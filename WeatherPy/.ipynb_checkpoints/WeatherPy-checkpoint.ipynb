# Processing Record 38 of Set 3 | al bahah
# Processing Record 39 of Set 3 | port mathurin
# Processing Record 40 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 3 | namtsy
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | agat village
# Processing Record 44 of Set 3 | chunskiy
# Processing Record 45 of Set 3 | iskateley
# Processing Record 46 of Set 3 | muisne
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | manta
# Processing Record 0 of Set 4 | san antonio de pale
# Processing Record 1 of Set 4 | ust'-ilimsk
# Processing Record 2 of Set 4 | bamboo flat
# Processing Record 3 of Set 4 | uchiza
# Processing Record 4 of Set 4 | keflavik
# Processing Record 5 of Set 4 | slutsk
# Processing Record 6 of Set 4 | morondava
# Processing Record 7 of Set 4 | divnogorsk
# Processing Record 8 of Set 4 | udachny
# Processing Record 9 of Set 4 | tadine
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | nagqu
# Processing Record 14 of Set 4 | alice springs
# Processing Record 15 of Set 4 | sao jose da coroa grande
# Processing Record 16 of Set 4 | uglegorsk
# Processing Record 17 of Set 4 | kourou
# Processing Record 18 of Set 4 | pangani
# Processing Record 19 of Set 4 | rexburg
# Processing Record 20 of Set 4 | beihai
# Processing Record 21 of Set 4 | kembe
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | malango
# Processing Record 24 of Set 4 | ceelbuur
# Processing Record 25 of Set 4 | severnoye
# Processing Record 26 of Set 4 | okhotsk
# Processing Record 27 of Set 4 | novodvinsk
# Processing Record 28 of Set 4 | sant cristofol de les fonts
# Processing Record 29 of Set 4 | saynshand
# Processing Record 30 of Set 4 | castillos
# Processing Record 31 of Set 4 | tual
# Processing Record 32 of Set 4 | el-tor
# Processing Record 33 of Set 4 | nabire
# Processing Record 34 of Set 4 | alesund
# Processing Record 35 of Set 4 | blackmans bay
# Processing Record 36 of Set 4 | bonthe
# Processing Record 37 of Set 4 | kone
# Processing Record 38 of Set 4 | saskatoon
# Processing Record 39 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | cafayate
# Processing Record 42 of Set 4 | wanning
# Processing Record 43 of Set 4 | laem sing
# Processing Record 44 of Set 4 | sambava
# Processing Record 45 of Set 4 | st. john's
# Processing Record 46 of Set 4 | geidam
# Processing Record 47 of Set 4 | laurens
# Processing Record 48 of Set 4 | kyaikkami
# Processing Record 49 of Set 4 | olyokminsk
# Processing Record 0 of Set 5 | tilcara
# Processing Record 1 of Set 5 | howard springs
# Processing Record 2 of Set 5 | warmbad
# Processing Record 3 of Set 5 | victoria point
# Processing Record 4 of Set 5 | pariaman
# Processing Record 5 of Set 5 | marsaskala
# City not found. Skipping...
# Processing Record 6 of Set 5 | luena
# Processing Record 7 of Set 5 | terenozek
# Processing Record 8 of Set 5 | cam ranh
# Processing Record 9 of Set 5 | college
# Processing Record 10 of Set 5 | sinabang
# Processing Record 11 of Set 5 | papatowai
# Processing Record 12 of Set 5 | papao
# Processing Record 13 of Set 5 | howrah
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | benghazi
# Processing Record 16 of Set 5 | ketou
# Processing Record 17 of Set 5 | sao vicente
# Processing Record 18 of Set 5 | cassia
# Processing Record 19 of Set 5 | olonkinbyen
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | butembo
# Processing Record 22 of Set 5 | ndele
# Processing Record 23 of Set 5 | zambezi
# Processing Record 24 of Set 5 | isle of lewis
# City not found. Skipping...
# Processing Record 25 of Set 5 | karoi
# Processing Record 26 of Set 5 | lihue
# Processing Record 27 of Set 5 | sidney
# Processing Record 28 of Set 5 | ust-nera
# Processing Record 29 of Set 5 | andovoranto
# Processing Record 30 of Set 5 | horishni plavni
# Processing Record 31 of Set 5 | kailua-kona
# Processing Record 32 of Set 5 | sangre grande
# Processing Record 33 of Set 5 | kuantan
# Processing Record 34 of Set 5 | cody
# Processing Record 35 of Set 5 | ulladulla
# Processing Record 36 of Set 5 | colonia
# Processing Record 37 of Set 5 | champerico
# Processing Record 38 of Set 5 | argo
# Processing Record 39 of Set 5 | valley city
# Processing Record 40 of Set 5 | nyurba
# Processing Record 41 of Set 5 | chambersburg
# Processing Record 42 of Set 5 | abalak
# Processing Record 43 of Set 5 | ubinskoye
# Processing Record 44 of Set 5 | porto novo
# Processing Record 45 of Set 5 | atafu village
# Processing Record 46 of Set 5 | kismayo
# Processing Record 47 of Set 5 | walvis bay
# Processing Record 48 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 5 | flying fish cove
# Processing Record 0 of Set 6 | tisul'
# Processing Record 1 of Set 6 | arvada
# Processing Record 2 of Set 6 | holualoa
# Processing Record 3 of Set 6 | caninde
# Processing Record 4 of Set 6 | aykhal
# Processing Record 5 of Set 6 | zaysan
# Processing Record 6 of Set 6 | chibougamau
# Processing Record 7 of Set 6 | harstad
# Processing Record 8 of Set 6 | la ronge
# Processing Record 9 of Set 6 | kirensk
# Processing Record 10 of Set 6 | peniche
# Processing Record 11 of Set 6 | marsh harbour
# Processing Record 12 of Set 6 | berezovyy
# Processing Record 13 of Set 6 | bengaluru
# Processing Record 14 of Set 6 | midvagur
# Processing Record 15 of Set 6 | lashio
# Processing Record 16 of Set 6 | dickinson
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | santa cruz
# Processing Record 19 of Set 6 | aden
# Processing Record 20 of Set 6 | saipan
# Processing Record 21 of Set 6 | kargasok
# Processing Record 22 of Set 6 | iquitos
# Processing Record 23 of Set 6 | saint-joseph
# Processing Record 24 of Set 6 | al burayqah
# Processing Record 25 of Set 6 | mungwi
# Processing Record 26 of Set 6 | la'ie
# Processing Record 27 of Set 6 | hadibu
# Processing Record 28 of Set 6 | nadi
# Processing Record 29 of Set 6 | hengchun
# Processing Record 30 of Set 6 | libreville
# Processing Record 31 of Set 6 | overath
# Processing Record 32 of Set 6 | gallivare
# City not found. Skipping...
# Processing Record 33 of Set 6 | east ballina
# Processing Record 34 of Set 6 | happy valley-goose bay
# Processing Record 35 of Set 6 | funafuti
# Processing Record 36 of Set 6 | atar
# Processing Record 37 of Set 6 | east london
# Processing Record 38 of Set 6 | minas de matahambre
# City not found. Skipping...
# Processing Record 39 of Set 6 | hawaiian paradise park
# Processing Record 40 of Set 6 | pimentel
# Processing Record 41 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 6 | cidreira
# Processing Record 43 of Set 6 | baiti
# Processing Record 44 of Set 6 | inari
# Processing Record 45 of Set 6 | shalqar
# Processing Record 46 of Set 6 | kargopol'
# Processing Record 47 of Set 6 | port augusta
# Processing Record 48 of Set 6 | beira
# Processing Record 49 of Set 6 | anadyr
# Processing Record 0 of Set 7 | guerrero negro
# Processing Record 1 of Set 7 | vorkuta
# Processing Record 2 of Set 7 | tura
# Processing Record 3 of Set 7 | baiculesti
# Processing Record 4 of Set 7 | badajoz
# Processing Record 5 of Set 7 | bodo
# Processing Record 6 of Set 7 | chilecito
# Processing Record 7 of Set 7 | as sulayyil
# Processing Record 8 of Set 7 | kirksville
# Processing Record 9 of Set 7 | independencia
# Processing Record 10 of Set 7 | valparaiso
# Processing Record 11 of Set 7 | anzio
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | adelaide
# Processing Record 14 of Set 7 | argostolion
# Processing Record 15 of Set 7 | saldanha
# Processing Record 16 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 17 of Set 7 | west end
# Processing Record 18 of Set 7 | haiku-pauwela
# Processing Record 19 of Set 7 | pasni
# Processing Record 20 of Set 7 | freetown
# Processing Record 21 of Set 7 | chuzhou
# Processing Record 22 of Set 7 | tanggu
# Processing Record 23 of Set 7 | colares
# Processing Record 24 of Set 7 | chui
# Processing Record 25 of Set 7 | severo-yeniseyskiy
# Processing Record 26 of Set 7 | saurimo
# Processing Record 27 of Set 7 | borujen
# Processing Record 28 of Set 7 | sabang
# Processing Record 29 of Set 7 | sakhipur
# Processing Record 30 of Set 7 | kuching
# Processing Record 31 of Set 7 | valle de la pascua
# Processing Record 32 of Set 7 | umm kaddadah
# Processing Record 33 of Set 7 | lincoln city
# Processing Record 34 of Set 7 | libertad
# Processing Record 35 of Set 7 | huainan
# Processing Record 36 of Set 7 | westport
# Processing Record 37 of Set 7 | villa de cos
# Processing Record 38 of Set 7 | betio village
# Processing Record 39 of Set 7 | tazacorte
# Processing Record 40 of Set 7 | miahuatlan
# Processing Record 41 of Set 7 | nar'yan-mar
# Processing Record 42 of Set 7 | dadonghai
# City not found. Skipping...
# Processing Record 43 of Set 7 | kidal
# Processing Record 44 of Set 7 | banjarmasin
# Processing Record 45 of Set 7 | mount gambier
# Processing Record 46 of Set 7 | san rafael del yuma
# Processing Record 15 of Set 9 | n'zeto
# Processing Record 16 of Set 9 | thinadhoo
# Processing Record 17 of Set 9 | morehead city
# Processing Record 18 of Set 9 | miranda
# Processing Record 19 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 9 | eyl
# Processing Record 21 of Set 9 | oxford
# Processing Record 22 of Set 9 | businga
# Processing Record 23 of Set 9 | zalingei
# Processing Record 24 of Set 9 | vallenar
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | kingaroy
# Processing Record 27 of Set 9 | gallup
# Processing Record 28 of Set 9 | xinyuan
# Processing Record 29 of Set 9 | san rafael
# Processing Record 30 of Set 9 | malvan
# Processing Record 31 of Set 9 | tofol
# Processing Record 32 of Set 9 | revelstoke
# Processing Record 33 of Set 9 | mahina
# Processing Record 34 of Set 9 | mirny
# Processing Record 35 of Set 9 | hilo
# Processing Record 36 of Set 9 | sitka
# Processing Record 37 of Set 9 | miquelon
# Processing Record 38 of Set 9 | tsiombe
# Processing Record 39 of Set 9 | mani
# Processing Record 40 of Set 9 | spitak
# Processing Record 41 of Set 9 | piracaia
# Processing Record 42 of Set 9 | kerikeri
# Processing Record 43 of Set 9 | areka
# Processing Record 44 of Set 9 | visakhapatnam
# Processing Record 45 of Set 9 | tomaszow mazowiecki
# Processing Record 46 of Set 9 | chul'man
# Processing Record 47 of Set 9 | brookings
# Processing Record 48 of Set 9 | kalabo
# Processing Record 49 of Set 9 | albufeira
# Processing Record 0 of Set 10 | kayangel
# Processing Record 1 of Set 10 | newman
# Processing Record 2 of Set 10 | tshabong
# Processing Record 3 of Set 10 | kavarna
# Processing Record 4 of Set 10 | revda
# Processing Record 5 of Set 10 | wesselsbron
# Processing Record 6 of Set 10 | mokwa
# Processing Record 7 of Set 10 | namibe
# Processing Record 8 of Set 10 | tateyama
# Processing Record 9 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 10 | fort mcmurray
# Processing Record 11 of Set 10 | elliot lake
# Processing Record 12 of Set 10 | kabare
# Processing Record 13 of Set 10 | bushehr
# Processing Record 14 of Set 10 | ugoofaaru
# Processing Record 15 of Set 10 | cabedelo
# Processing Record 16 of Set 10 | jining
# Processing Record 17 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 10 | katsuren-haebaru
# Processing Record 19 of Set 10 | tralee
# Processing Record 20 of Set 10 | maitum
# Processing Record 21 of Set 10 | horta
# Processing Record 22 of Set 10 | tiszaalpar
# Processing Record 23 of Set 10 | prince rupert
# Processing Record 24 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 25 of Set 10 | sena madureira
# Processing Record 26 of Set 10 | moussoro
# Processing Record 27 of Set 10 | larkird
# Processing Record 28 of Set 10 | hirara
# Processing Record 29 of Set 10 | arraial do cabo
# Processing Record 30 of Set 10 | katabu
# Processing Record 31 of Set 10 | porbandar
# Processing Record 32 of Set 10 | kamen'-na-obi
# Processing Record 33 of Set 10 | friedeburg
# Processing Record 34 of Set 10 | kapuskasing
# Processing Record 35 of Set 10 | remire-montjoly
# Processing Record 36 of Set 10 | meulaboh
# Processing Record 37 of Set 10 | asau
# Processing Record 38 of Set 10 | dolores
# Processing Record 39 of Set 10 | namie
# Processing Record 40 of Set 10 | iowa falls
# Processing Record 41 of Set 10 | acapulco de juarez
# Processing Record 42 of Set 10 | tabas
# Processing Record 43 of Set 10 | nguigmi
# Processing Record 44 of Set 10 | carbonear
# Processing Record 45 of Set 10 | enoch
# Processing Record 46 of Set 10 | manokwari
# Processing Record 47 of Set 10 | sorong
# Processing Record 48 of Set 10 | wamba
# Processing Record 49 of Set 10 | anna regina
# Processing Record 0 of Set 11 | belyy yar
# Processing Record 1 of Set 11 | hami
# Processing Record 2 of Set 11 | bykovo
# Processing Record 3 of Set 11 | dalandzadgad
# Processing Record 4 of Set 11 | kiunga
# Processing Record 5 of Set 11 | halifax
# Processing Record 6 of Set 11 | las tablas
# Processing Record 7 of Set 11 | kingston
# Processing Record 8 of Set 11 | taoudenni
# Processing Record 9 of Set 11 | mokhsogollokh
# Processing Record 10 of Set 11 | kappelrodeck
# Processing Record 11 of Set 11 | quepos
# Processing Record 12 of Set 11 | mezhdurechenskiy
# Processing Record 13 of Set 11 | khovd
# Processing Record 14 of Set 11 | tsengel
# Processing Record 15 of Set 11 | klyuchi
# Processing Record 16 of Set 11 | kolonia town
# Processing Record 17 of Set 11 | longonjo
# Processing Record 18 of Set 11 | cabo san lucas
# Processing Record 19 of Set 11 | ascension
# Processing Record 20 of Set 11 | ishigaki
# Processing Record 21 of Set 11 | miyanoura
# City not found. Skipping...
# Processing Record 22 of Set 11 | thunder bay
# Processing Record 23 of Set 11 | hotan
# Processing Record 24 of Set 11 | dwarka
# Processing Record 25 of Set 11 | zarate
# Processing Record 26 of Set 11 | plymouth
# Processing Record 27 of Set 11 | bardai
# Processing Record 28 of Set 11 | gebeit
# Processing Record 29 of Set 11 | priozersk
# Processing Record 30 of Set 11 | nizhniy odes
# Processing Record 31 of Set 11 | kindu
# Processing Record 32 of Set 11 | yeniseysk
# Processing Record 33 of Set 11 | maues
# Processing Record 34 of Set 11 | alaghsas
# Processing Record 35 of Set 11 | bandon
# Processing Record 36 of Set 11 | fort st. john
# Processing Record 37 of Set 11 | chak thirty-one -eleven left
# Processing Record 38 of Set 11 | thohoyandou
# Processing Record 39 of Set 11 | askino
# Processing Record 40 of Set 11 | pavlodar
# Processing Record 41 of Set 11 | mweka
# Processing Record 42 of Set 11 | olgii
# City not found. Skipping...
# Processing Record 43 of Set 11 | monte argentario
# Processing Record 44 of Set 11 | dakhla
# Processing Record 45 of Set 11 | naberera
# Processing Record 46 of Set 11 | mochudi
# Processing Record 47 of Set 11 | francisco i. madero
# Processing Record 48 of Set 11 | al ghayzah
# Processing Record 49 of Set 11 | forster
# Processing Record 0 of Set 12 | port sudan
# Processing Record 1 of Set 12 | salinas
# Processing Record 2 of Set 12 | vila franca do campo
# Processing Record 3 of Set 12 | kano
# Processing Record 4 of Set 12 | ylitornio
# Processing Record 5 of Set 12 | kroya
# Processing Record 6 of Set 12 | santo antonio
# Processing Record 7 of Set 12 | laojunmiao
# Processing Record 8 of Set 12 | dhidhdhoo
# Processing Record 9 of Set 12 | saudarkrokur
# Processing Record 10 of Set 12 | callaway
# Processing Record 11 of Set 12 | bulungu
# Processing Record 12 of Set 12 | chingirlau
# Processing Record 13 of Set 12 | kyren
# Processing Record 14 of Set 12 | manistee
# Processing Record 15 of Set 12 | vozhega
# Processing Record 16 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 17 of Set 12 | posto fiscal rolim de moura
# Processing Record 18 of Set 12 | sheridan
# Processing Record 19 of Set 12 | alta
# Processing Record 20 of Set 12 | el granada
# Processing Record 21 of Set 12 | belomorsk
# Processing Record 22 of Set 12 | jijiga
# Processing Record 23 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 24 of Set 12 | niquero
# Processing Record 25 of Set 12 | buala
# Processing Record 26 of Set 12 | bairnsdale
# Processing Record 27 of Set 12 | ternate
# Processing Record 28 of Set 12 | fortuna
# Processing Record 29 of Set 12 | yoichi
# Processing Record 30 of Set 12 | port macquarie
# Processing Record 31 of Set 12 | phetchaburi
# Processing Record 32 of Set 12 | belinskiy
# Processing Record 33 of Set 12 | rajgarh
# Processing Record 34 of Set 12 | mugia
# Processing Record 35 of Set 12 | lompoc
# Processing Record 36 of Set 12 | winnemucca
# Processing Record 37 of Set 12 | luderitz
# Processing Record 38 of Set 12 | murzuq
# Processing Record 39 of Set 12 | brisas de zicatela
# Processing Record 40 of Set 12 | maintirano
# Processing Record 41 of Set 12 | estevan
# Processing Record 42 of Set 12 | grand falls-windsor
# Processing Record 43 of Set 12 | galesong
# Processing Record 44 of Set 12 | rongelap
# Processing Record 45 of Set 12 | marietta
# Processing Record 46 of Set 12 | usinsk
# Processing Record 47 of Set 12 | dolneni
# Processing Record 48 of Set 12 | la feria
# Processing Record 49 of Set 12 | la asuncion
# Processing Record 0 of Set 13 | griffith
# Processing Record 1 of Set 13 | dexter
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       grytviken -54.2811  -36.5092      0.60        83          69
# 1      gadzhiyevo  69.2551   33.3362     -2.81        62         100
# 2           ancud -41.8697  -73.8203      6.57        94          97
# 3  island harbour  50.7240   -1.2758     13.43        73         100
# 4            ta`u -14.2336 -169.5144     28.67        81         100
#
#    Wind Speed Country        Date
# 0        4.34      GS  1715035486
# 1        7.54      RU  1715035486
# 2        1.05      CL  1715035454
# 3        1.79      GB  1715035487
# 4        4.15      AS  1715035487

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             grytviken -54.2811  -36.5092      0.60        83          69
# 1            gadzhiyevo  69.2551   33.3362     -2.81        62         100
# 2                 ancud -41.8697  -73.8203      6.57        94          97
# 3        island harbour  50.7240   -1.2758     13.43        73         100
# 4                  ta`u -14.2336 -169.5144     28.67        81         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.34      GS  1715035486
# 1              7.54      RU  1715035486
# 2              1.05      CL  1715035454
# 3              1.79      GB  1715035487
# 4              4.15      AS  1715035487

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], 
            color='blue', alpha=0.5, edgecolors='black', s=50)

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], 
            color='green', alpha=0.5, edgecolors='black', s=50)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], 
            color='grey', alpha=0.5, edgecolors='black', s=50)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], 
            color='purple', alpha=0.5, edgecolors='black', s=50)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title):
     # Calculate the linear regression
    (slope, intercept, rvalue, _, _) = linregress(x_values, y_values)
    
    # Calculate regression values to plot the line
    reg_values = x_values * slope + intercept

    # Create scatter plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, reg_values, "r-")  # red line for the regression line

    # Annotate the line equation on the plot
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=15, color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            gadzhiyevo  69.2551   33.3362     -2.81        62         100
# 3        island harbour  50.7240   -1.2758     13.43        73         100
# 5                kodiak  57.7900 -152.4072      7.73        76         100
# 6               mukalla  14.5425   49.1242     28.46        80           6
# 9              hamilton  39.1834  -84.5333     21.97        90         100
#
#          Wind Speed Country        Date
# City_ID
# 1              7.54      RU  1715035486
# 3              1.79      GB  1715035487
# 5              4.63      US  1715035487
# 6              2.50      YE  1715035487
# 9              2.06      US  1715035488

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                grytviken -54.2811  -36.5092      0.60        83          69
# 2                    ancud -41.8697  -73.8203      6.57        94          97
# 4                     ta`u -14.2336 -169.5144     28.67        81         100
# 7        port-aux-francais -49.3500   70.2167      6.71        97         100
# 8                 waitangi -43.9535 -176.5597     11.57        88          90
#
#          Wind Speed Country        Date
# City_ID
# 0              4.34      GS  1715035486
# 2              1.05      CL  1715035454
# 4              4.15      AS  1715035487
# 7             13.22      TF  1715035376
# 8              1.79      NZ  1715035487

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='blue', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: -0.8719689492057391

# %%
# Linear regression on Southern Hemisphere
# Extract latitude and maximum temperature data
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='blue', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: 0.7795263313988307

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
#     The R-value of -0.87 indicates a strong negative correlation between temperature and latitude.
#     The scatter plot shows a clear downtrend, meaning that as the latitude increases (moving away from the equator toward the poles), the temperature tends to decrease.
#     This is consistent with the general climatic trend where regions further north (higher latitudes) tend to have colder climates.
#
# Southern Hemisphere:
#     The R-value of 0.77 shows a strong positive correlation between temperature and latitude.
#     The scatter plot depicts a distinct upward trend, indicating that as latitude decreases (moving toward the equator from the southernmost regions), the temperature generally increases.
#     This positive trend aligns with the expected climatic pattern where regions closer to the equator are generally warmer.
#
# In summary, both hemispheres display clear linear relationships between temperature and latitude. While temperatures decrease with increasing latitude in the Northern Hemisphere, they increase with decreasing latitude in the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='green', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: 0.1293785898333329

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='green', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: 0.12205739187949663

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
#     The R-value of 0.12 indicates a very weak positive correlation between humidity and latitude.
#     The scatter plot appears scattered with no clear trend, suggesting that changes in latitude do not significantly affect humidity in the Northern Hemisphere.
#     This weak correlation implies that other factors may have more influence on humidity than latitude alone.
#
# Southern Hemisphere:
#     The R-value of 0.12 similarly indicates a very weak positive correlation between humidity and latitude.
#     The scatter plot is scattered, showing no discernible pattern that connects latitude to humidity levels.
#     As with the Northern Hemisphere, this weak correlation suggests that factors other than latitude primarily affect humidity levels in the Southern Hemisphere.
#
# In summary, both hemispheres show a weak relationship between humidity and latitude, and no strong trends emerge from the data.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='grey', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: 0.15631776287876634

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='grey', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: 0.199808456152119

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
#     The R-value of 0.15 indicates a weak positive correlation between cloudiness and latitude.
#     The scatter plot is scattered, showing no clear pattern or trend. This suggests that latitude has little influence on cloudiness in the Northern Hemisphere.
#     The weak correlation implies that other factors are more impactful in determining cloudiness levels.
#
# Southern Hemisphere:
#     The R-value of 0.19 also shows a weak positive correlation between cloudiness and latitude.
#     The scatter plot is similarly scattered without a discernible trend, indicating that cloudiness is not strongly affected by latitude in the Southern Hemisphere.
#     As with the Northern Hemisphere, this weak relationship emphasizes that other factors play a more significant role in influencing cloudiness.
#
# In summary, the weak correlations in both hemispheres suggest that latitude is not a significant predictor of cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='purple', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: 0.061925410012164804

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Perform linear regression
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)

# Calculate the regression values for plotting
regression_line = x_values * slope + intercept

# Create a scatter plot
plt.scatter(x_values, y_values, color='purple', edgecolors='black')
plt.plot(x_values, regression_line, "r-", label=f"y = {slope:.2f}x + {intercept:.2f}")

# Annotate the plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.legend(loc='best')

# Show plot
plt.show()

# Print the R-value
print(f"The r-value (correlation coefficient) is: {r_value}")
# Out:
# The r-value (correlation coefficient) is: -0.09625114980325448

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
#     An R-value of 0.06 indicates an extremely weak positive correlation between wind speed and latitude.
#     The scatter plot is scattered without a clear pattern, showing no significant linear relationship between these variables.
#     This weak correlation suggests that latitude has little to no influence on wind speed in the Northern Hemisphere.
#
# Southern Hemisphere:
#     An R-value of -0.09 indicates an extremely weak negative correlation between wind speed and latitude.
#     The scatter plot also appears scattered, with no distinct linear trend visible.
#     As in the Northern Hemisphere, this weak correlation suggests that wind speed is largely influenced by other factors.
#
# In summary, the analysis shows that both hemispheres have very weak correlations between wind speed and latitude, implying that wind patterns are driven by other factors.
